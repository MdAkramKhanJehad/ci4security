# %% [markdown]
# # Binary Treatment Causal Analysis

# %%
import warnings
import re
import sys
from pathlib import Path

import graphviz
import numpy as np
import pandas as pd
from dowhy import CausalModel
from IPython.display import display
from sklearn.exceptions import DataConversionWarning
from sklearn.preprocessing import RobustScaler

warnings.filterwarnings("ignore", category=DataConversionWarning)


def find_repo_root(start=Path.cwd()):
    for candidate in [start, *start.parents]:
        if (candidate / "utils" / "statistical_tests.py").exists():
            return candidate
    raise RuntimeError("Could not find repo root containing utils/statistical_tests.py")


REPO_ROOT = find_repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from utils import statistical_tests as tests

# %%
INPUT_FILE = "alerts_with_lib_category_and_apk_size_codeql.csv"


def normalize_verdict(value):
    normalized = str(value).strip().lower()
    if normalized in {"1", "true"}:
        return 1
    if normalized in {"0", "false"}:
        return 0
    raise ValueError(f"Unsupported verdict value: {value!r}")


def normalize_rule_id(value):
    if pd.isna(value):
        return "missing"
    value = str(value).strip()
    if not value:
        return "missing"
    return re.sub(r"[^0-9A-Za-z_]+", "_", value)


def add_rule_id_confounders(data):
    rule_id_dummies = pd.get_dummies(data["rule_id"], prefix="rule_id", drop_first=True, dtype=int)
    return pd.concat([data, rule_id_dummies], axis=1), list(rule_id_dummies.columns)


df = pd.read_csv(INPUT_FILE)
print("Original rows:", len(df))

df = df[~df["code_location"].str.contains("obfuscated", case=False, na=False)].copy()
print("After removing obfuscated:", len(df))

df["verdict"] = df["verdict"].apply(normalize_verdict)
df["is_third_party"] = (~df["code_location"].isin(["developer_written"])).astype(int)
df["lib_category"] = df["code_location"].apply(lambda x: x if x != "developer_written" else "source")

rule_id_source_column = "rule_id" if "rule_id" in df.columns else "ruleId"
df["rule_id"] = df[rule_id_source_column].apply(normalize_rule_id)

print("\nis_third_party counts:")
print(df["is_third_party"].value_counts())
# print("\n", df["rule_id"].head(10))

# Combined treatment: 1 means all classified alerts are reported; 0 means developer-written-only alerts are reported.
df_all = df.copy()
df_all["combined"] = 1
df_developer_written = df[df["code_location"] == "developer_written"].copy()
df_developer_written["combined"] = 0
df = pd.concat([df_all, df_developer_written], ignore_index=True)

print("\nVerdict value counts:")
print(df["verdict"].value_counts())
print("\nCode location value counts:")
print(df["code_location"].value_counts())
print("\nTop rule_id counts:")
print(df["rule_id"].value_counts().head(20))
# Out:
# Original rows: 21501
# After removing obfuscated: 21501
#
# is_third_party counts:
# is_third_party
# 1    20947
# 0      554
# Name: count, dtype: int64
#
# Verdict value counts:
# verdict
# 1    19634
# 0     2421
# Name: count, dtype: int64
#
# Code location value counts:
# code_location
# Android              9345
# others               6367
# Utilities            4522
# developer_written    1108
# SocialMedia           506
# Cloud                 180
# Analytics              27
# Name: count, dtype: int64
#
# Top rule_id counts:
# rule_id
# java_potentially_weak_cryptographic_algorithm    13221
# java_weak_cryptographic_algorithm                 4418
# java_unsafe_tls_version                           1987
# java_unsafe_cert_trust                             824
# java_static_initialization_vector                  627
# java_rsa_without_oaep                              447
# java_insecure_trustmanager                         263
# java_insufficient_key_size                          73
# java_insecure_randomness                            50
# java_hash_without_salt                              45
# java_disabled_certificate_revocation_checking       32
# java_unsafe_hostname_verification                   20
# java_android_missing_certificate_pinning            14
# java_predictable_seed                               11
# java_improper_webview_certificate_validation         9
# java_insecure_smtp_ssl                               8
# java_insecure_basic_auth                             6
# Name: count, dtype: int64

# %%
scaler = RobustScaler()
df["apk_size_scaled"] = scaler.fit_transform(df[["apk_size"]])

category_order = [
    "<100",
    "100-500",
    "500-1k",
    "1k-5k",
    "5k-10k",
    "10k-50k",
    "50k-100k",
    "100k-500k",
    "500k-1M",
    "1M-5M",
    ">5M",
]

popularity_column = "app_popularity" if "app_popularity" in df.columns else "apk_category"
df["app_popularity_encoded"] = pd.Categorical(
    df[popularity_column],
    categories=category_order,
    ordered=True,
).codes

df, rule_id = add_rule_id_confounders(df)
common_causes = ["app_popularity_encoded", *rule_id]

print("Rule ID confounder columns:", len(rule_id))
print(rule_id[:20])
# Out:
# Rule ID confounder columns: 16
# ['rule_id_java_disabled_certificate_revocation_checking', 'rule_id_java_hash_without_salt', 'rule_id_java_improper_webview_certificate_validation', 'rule_id_java_insecure_basic_auth', 'rule_id_java_insecure_randomness', 'rule_id_java_insecure_smtp_ssl', 'rule_id_java_insecure_trustmanager', 'rule_id_java_insufficient_key_size', 'rule_id_java_potentially_weak_cryptographic_algorithm', 'rule_id_java_predictable_seed', 'rule_id_java_rsa_without_oaep', 'rule_id_java_static_initialization_vector', 'rule_id_java_unsafe_cert_trust', 'rule_id_java_unsafe_hostname_verification', 'rule_id_java_unsafe_tls_version', 'rule_id_java_weak_cryptographic_algorithm']

# %%
def all_correlation_tests():
    tests.kruskal_test_continuous_by_groups(df, "app_popularity_encoded", "apk_size_scaled")

    tests.logistic_regression_numeric_to_binary(df, "app_popularity_encoded", "verdict")
    tests.chi_square_test_cat_to_binary(df, "app_popularity_encoded", "verdict")
    tests.logistic_regression_numeric_to_binary(df, "app_popularity_encoded", "combined")
    tests.chi_square_test_cat_to_binary(df, "app_popularity_encoded", "combined")

    tests.logistic_regression_numeric_to_binary(df, "apk_size_scaled", "verdict")
    tests.mann_whitney_test(df, "apk_size_scaled", "verdict")
    tests.logistic_regression_numeric_to_binary(df, "apk_size_scaled", "combined")
    tests.mann_whitney_test(df, "apk_size_scaled", "combined")

    tests.logistic_regression_binary_to_binary(df, "is_third_party", "verdict")
    tests.chi_square_test_cat_to_binary(df, "is_third_party", "verdict")

    tests.chi_square_test_cat_to_binary(df, "rule_id", "verdict")
    tests.chi_square_test_cat_to_binary(df, "rule_id", "combined")

    tests.logistic_regression_binary_to_binary(df, "combined", "verdict")
    tests.correlation_test_treatment_to_outcome(df)


all_correlation_tests()
# Out:
# app_popularity_encoded -> apk_size_scaled (Kruskal-Wallis)
# H = 5172.710, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# app_popularity_encoded -> verdict (Logistic regression)
# coef = 0.0503, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# app_popularity_encoded -> verdict (Chi-square)
# chi2 = 138.319, dof = 10, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# app_popularity_encoded -> combined (Logistic regression)
# coef = 0.0396, p = 0.0017
# Edge is not rejected (p < 0.05)
#
# app_popularity_encoded -> combined (Chi-square)
# chi2 = 62.890, dof = 10, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# apk_size_scaled -> verdict (Logistic regression)
# coef = -0.0787, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# apk_size_scaled -> verdict (Mann-Whitney U)
# U = 25106193.000, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# apk_size_scaled -> combined (Logistic regression)
# coef = 0.0114, p = 0.7681
# Edge is rejected (p >= 0.05)
#
# apk_size_scaled -> combined (Mann-Whitney U)
# U = 5810381.000, p = 0.3258
# Edge is rejected (p >= 0.05)
#
# is_third_party -> verdict (Logistic regression)
# coef = -0.9109, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# is_third_party -> verdict (Chi-square)
# chi2 = 43.817, dof = 1, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# rule_id -> verdict (Chi-square)
# chi2 = 11049.901, dof = 16, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# rule_id -> combined (Chi-square)
# chi2 = 884.784, dof = 16, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# combined -> verdict (Logistic regression)
# coef = -0.8943, p = 0.0000
# Edge is not rejected (p < 0.05)
#
# combined -> verdict (Spearman)
# rho = -0.0313, p = 0.0000

# %%
rule_id_edges = "\n".join(
    f"    {column} -> combined;\n    {column} -> verdict;" for column in rule_id
)

display_graph = """
digraph {
    combined -> verdict;
    apk_size_scaled -> verdict;
    is_third_party -> verdict;
    app_popularity_encoded -> combined;
    app_popularity_encoded -> verdict;
    app_popularity_encoded -> apk_size_scaled;
    rule_id -> combined;
    rule_id -> verdict;
}
"""

model_graph = f"""
digraph {{
    combined -> verdict;
    apk_size_scaled -> verdict;
    is_third_party -> verdict;
    app_popularity_encoded -> combined;
    app_popularity_encoded -> verdict;
    app_popularity_encoded -> apk_size_scaled;
{rule_id_edges}
}}
"""

display(graphviz.Source(display_graph))

model = CausalModel(
    data=df,
    treatment="combined",
    outcome="verdict",
    graph=model_graph.replace("\n", " "),
    common_causes=common_causes,
)

identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print("\n------- Identified estimand -------")
print(identified_estimand)
# Out:
# ------- Identified estimand -------
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d                                                                         ↪
# ───────────(E[verdict|rule_id_java_predictable_seed,is_third_party,rule_id_jav ↪
# d[combined]                                                                    ↪
#
# ↪                                                                              ↪
# ↪ a_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_ce ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ rtificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_st ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ atic_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecu ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ re_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trus ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ t,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cry ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_ ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_c ↪
# ↪                                                                              ↪
#
# ↪
# ↪ ryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size])
# ↪
# Estimand assumption 1, Unconfoundedness: If U→{combined} and U→verdict then P(verdict|combined,rule_id_java_predictable_seed,is_third_party,rule_id_java_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_certificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecure_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cryptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_cryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size,U) = P(verdict|combined,rule_id_java_predictable_seed,is_third_party,rule_id_java_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_certificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecure_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cryptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_cryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!
#
# ### Estimand : 4
# Estimand name: general_adjustment
# Estimand expression:
#      d                                                                         ↪
# ───────────(E[verdict|rule_id_java_predictable_seed,rule_id_java_unsafe_cert_t ↪
# d[combined]                                                                    ↪
#
# ↪                                                                              ↪
# ↪ rust,rule_id_java_improper_webview_certificate_validation,rule_id_java_insec ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ure_randomness,rule_id_java_hash_without_salt,rule_id_java_static_initializa ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ tion_vector,rule_id_java_insecure_smtp_ssl,rule_id_java_insecure_trustmanage ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ r,app_popularity_encoded,rule_id_java_weak_cryptographic_algorithm,rule_id_j ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ava_potentially_weak_cryptographic_algorithm,rule_id_java_rsa_without_oaep,r ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ule_id_java_unsafe_hostname_verification,rule_id_java_unsafe_tls_version,rul ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ e_id_java_insufficient_key_size,rule_id_java_insecure_basic_auth,rule_id_jav ↪
# ↪                                                                              ↪
#
# ↪
# ↪ a_disabled_certificate_revocation_checking])
# ↪
# Estimand assumption 1, Unconfoundedness: If U→{combined} and U→verdict then P(verdict|combined,rule_id_java_predictable_seed,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_insecure_randomness,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_insecure_smtp_ssl,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_weak_cryptographic_algorithm,rule_id_java_potentially_weak_cryptographic_algorithm,rule_id_java_rsa_without_oaep,rule_id_java_unsafe_hostname_verification,rule_id_java_unsafe_tls_version,rule_id_java_insufficient_key_size,rule_id_java_insecure_basic_auth,rule_id_java_disabled_certificate_revocation_checking,U) = P(verdict|combined,rule_id_java_predictable_seed,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_insecure_randomness,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_insecure_smtp_ssl,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_weak_cryptographic_algorithm,rule_id_java_potentially_weak_cryptographic_algorithm,rule_id_java_rsa_without_oaep,rule_id_java_unsafe_hostname_verification,rule_id_java_unsafe_tls_version,rule_id_java_insufficient_key_size,rule_id_java_insecure_basic_auth,rule_id_java_disabled_certificate_revocation_checking)

# %%
estimate = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.propensity_score_matching",
    target_units="ate",
    test_significance=True,
    confidence_intervals="bootstrap",
    method_params={
        "num_simulations": 300,
        "sample_size_fraction": 1.0,
        "confidence_level": 0.95,
    },
)

print("\n------- Causal effect estimate -------")
print(estimate)
# Out:
# ------- Causal effect estimate -------
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d                                                                         ↪
# ───────────(E[verdict|rule_id_java_predictable_seed,is_third_party,rule_id_jav ↪
# d[combined]                                                                    ↪
#
# ↪                                                                              ↪
# ↪ a_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_ce ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ rtificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_st ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ atic_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecu ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ re_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trus ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ t,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cry ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_ ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_c ↪
# ↪                                                                              ↪
#
# ↪
# ↪ ryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size])
# ↪
# Estimand assumption 1, Unconfoundedness: If U→{combined} and U→verdict then P(verdict|combined,rule_id_java_predictable_seed,is_third_party,rule_id_java_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_certificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecure_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cryptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_cryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size,U) = P(verdict|combined,rule_id_java_predictable_seed,is_third_party,rule_id_java_unsafe_tls_version,rule_id_java_insecure_smtp_ssl,rule_id_java_disabled_certificate_revocation_checking,rule_id_java_hash_without_salt,rule_id_java_static_initialization_vector,rule_id_java_rsa_without_oaep,rule_id_java_insecure_basic_auth,rule_id_java_insecure_randomness,rule_id_java_unsafe_cert_trust,rule_id_java_improper_webview_certificate_validation,rule_id_java_weak_cryptographic_algorithm,rule_id_java_unsafe_hostname_verification,rule_id_java_insecure_trustmanager,app_popularity_encoded,rule_id_java_potentially_weak_cryptographic_algorithm,apk_size_scaled,rule_id_java_insufficient_key_size)
#
# ## Realized estimand
# b: verdict~combined+rule_id_java_predictable_seed+is_third_party+rule_id_java_unsafe_tls_version+rule_id_java_insecure_smtp_ssl+rule_id_java_disabled_certificate_revocation_checking+rule_id_java_hash_without_salt+rule_id_java_static_initialization_vector+rule_id_java_rsa_without_oaep+rule_id_java_insecure_basic_auth+rule_id_java_insecure_randomness+rule_id_java_unsafe_cert_trust+rule_id_java_improper_webview_certificate_validation+rule_id_java_weak_cryptographic_algorithm+rule_id_java_unsafe_hostname_verification+rule_id_java_insecure_trustmanager+app_popularity_encoded+rule_id_java_potentially_weak_cryptographic_algorithm+apk_size_scaled+rule_id_java_insufficient_key_size
# Target units: ate
#
# ## Estimate
# Mean value: 0.8422579913851734
# p-value: 0.12
# 95.0% confidence interval: (np.float64(0.837814554522784), np.float64(1.79446837451825))

# %%
estimate.interpret(method_name="textual_effect_interpreter")

refutation_methods = [
    "random_common_cause",
    "placebo_treatment_refuter",
    "data_subset_refuter",
    "dummy_outcome_refuter",
]

for method in refutation_methods:
    if method == "placebo_treatment_refuter":
        ref = model.refute_estimate(
            identified_estimand,
            estimate,
            method_name=method,
            placebo_type="permute",
            num_simulations=200,
        )
    elif method == "data_subset_refuter":
        ref = model.refute_estimate(
            identified_estimand,
            estimate,
            method_name=method,
            subset_fraction=0.8,
            num_simulations=200,
        )
    elif method == "dummy_outcome_refuter":
        ref = model.refute_estimate(
            identified_estimand,
            estimate,
            method_name=method,
            num_simulations=200,
        )
    else:
        ref = model.refute_estimate(identified_estimand, estimate, method_name=method)

    print(f"\nRefuter: {method}\n", ref)
# Out:
# Increasing the treatment variable(s) [combined] from 0 to 1 causes an increase of 0.8422579913851734 in the expected value of the outcome [['verdict']], over the data distribution/population represented by the dataset.
#
# Refuter: random_common_cause
#  Refute: Add a random common cause
# Estimated effect:0.8422579913851734
# New effect:0.842257991385173
# p value:1.0
#
#
# Refuter: placebo_treatment_refuter
#  Refute: Use a Placebo Treatment
# Estimated effect:0.8422579913851734
# New effect:0.001793697574246203
# p value:0.885
#
#
# Refuter: data_subset_refuter
#  Refute: Use a subset of data
# Estimated effect:0.8422579913851734
# New effect:0.6950504420766266
# p value:0.81
#
#
# Refuter: dummy_outcome_refuter
#  [<dowhy.causal_refuter.CausalRefutation object at 0x11fb37000>]
